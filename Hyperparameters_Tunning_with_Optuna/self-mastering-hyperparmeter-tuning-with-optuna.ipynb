# %%
import numpy as np
import pandas as pd
import optuna
import seaborn as sns

# %%
healthxp = sns.load_dataset('healthexp')
healthxp.head()
# Out:
#    Year        Country  Spending_USD  Life_Expectancy
# 0  1970        Germany       252.311             70.6
# 1  1970         France       192.143             72.2
# 2  1970  Great Britain       123.993             71.9
# 3  1970          Japan       150.437             72.0
# 4  1970            USA       326.961             70.9

# %%
healthxp = pd.get_dummies(healthxp)
healthxp
# Out:
#      Year  Spending_USD  Life_Expectancy  Country_Canada  Country_France  \
# 0    1970       252.311             70.6           False           False
# 1    1970       192.143             72.2           False            True
# 2    1970       123.993             71.9           False           False
# 3    1970       150.437             72.0           False           False
# 4    1970       326.961             70.9           False           False
# ..    ...           ...              ...             ...             ...
# 269  2020      6938.983             81.1           False           False
# 270  2020      5468.418             82.3           False            True
# 271  2020      5018.700             80.4           False           False
# 272  2020      4665.641             84.7           False           False
# 273  2020     11859.179             77.0           False           False
#
#      Country_Germany  Country_Great Britain  Country_Japan  Country_USA
# 0               True                  False          False        False
# 1              False                  False          False        False
# 2              False                   True          False        False
# 3              False                  False           True        False
# 4              False                  False          False         True
# ..               ...                    ...            ...          ...
# 269             True                  False          False        False
# 270            False                  False          False        False
# 271            False                   True          False        False
# 272            False                  False           True        False
# 273            False                  False          False         True
#
# [274 rows x 9 columns]

# %%
X = healthxp.drop(['Life_Expectancy'], axis = 1)
X.head()
# Out:
#    Year  Spending_USD  Country_Canada  Country_France  Country_Germany  \
# 0  1970       252.311           False           False             True
# 1  1970       192.143           False            True            False
# 2  1970       123.993           False           False            False
# 3  1970       150.437           False           False            False
# 4  1970       326.961           False           False            False
#
#    Country_Great Britain  Country_Japan  Country_USA
# 0                  False          False        False
# 1                  False          False        False
# 2                   True          False        False
# 3                  False           True        False
# 4                  False          False         True

# %%
y = healthxp["Life_Expectancy"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 34)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr = RandomForestRegressor(random_state = 34)

# %%
rfr.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=34)

# %%
y_pred = rfr.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 0.24521818181817784

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 0.10628972727272501

# %%
r2_score(y_test, y_pred)
# Out:
# 0.9909317700688961

# %%
import optuna

# %%
from sklearn.model_selection import cross_val_score

# %%
def objective(trial):
    hyperparams ={
    'n_estimators' : trial.suggest_int('n_estimators', 100, 1000),
    'max_depth' : trial.suggest_int('max_depth', 10, 50),
    'min_samples_split' : trial.suggest_int('min_samples_split', 2, 32),
    'min_samples_leaf' : trial.suggest_int('min_samples_leaf',1,32),
    'n_jobs' : -1
    }
    
    model = RandomForestRegressor(**hyperparams)
    score = cross_val_score(model, X_train, y_train, cv = 5, scoring = 'neg_mean_squared_error')
    return np.mean(score)

# %%
study = optuna.create_study(direction = 'maximize')
study.optimize(objective, n_trials = 20)
best_params = study.best_params
print("Best parameters found: ", best_params)
# Out:
# [I 2024-02-05 16:44:14,806] A new study created in memory with name: no-name-ddd7ed98-6b41-4b01-ae1c-a16b4a505cdc
# [I 2024-02-05 16:44:23,974] Trial 0 finished with value: -1.189354203730634 and parameters: {'n_estimators': 578, 'max_depth': 37, 'min_samples_split': 15, 'min_samples_leaf': 8}. Best is trial 0 with value: -1.189354203730634.
# [I 2024-02-05 16:44:30,053] Trial 1 finished with value: -3.091252948143261 and parameters: {'n_estimators': 397, 'max_depth': 40, 'min_samples_split': 23, 'min_samples_leaf': 30}. Best is trial 0 with value: -1.189354203730634.
# [I 2024-02-05 16:44:38,956] Trial 2 finished with value: -2.117843076576596 and parameters: {'n_estimators': 568, 'max_depth': 23, 'min_samples_split': 30, 'min_samples_leaf': 15}. Best is trial 0 with value: -1.189354203730634.
# [I 2024-02-05 16:44:44,075] Trial 3 finished with value: -2.3642065672934356 and parameters: {'n_estimators': 321, 'max_depth': 41, 'min_samples_split': 16, 'min_samples_leaf': 19}. Best is trial 0 with value: -1.189354203730634.
# [I 2024-02-05 16:44:55,280] Trial 4 finished with value: -2.718863162071613 and parameters: {'n_estimators': 722, 'max_depth': 24, 'min_samples_split': 18, 'min_samples_leaf': 26}. Best is trial 0 with value: -1.189354203730634.
# [I 2024-02-05 16:45:07,848] Trial 5 finished with value: -2.89541511045518 and parameters: {'n_estimators': 818, 'max_depth': 12, 'min_samples_split': 21, 'min_samples_leaf': 28}. Best is trial 0 with value: -1.189354203730634.
# [I 2024-02-05 16:45:11,882] Trial 6 finished with value: -0.7568127659020003 and parameters: {'n_estimators': 248, 'max_depth': 18, 'min_samples_split': 12, 'min_samples_leaf': 5}. Best is trial 6 with value: -0.7568127659020003.
# [I 2024-02-05 16:45:21,472] Trial 7 finished with value: -1.0698783758499935 and parameters: {'n_estimators': 604, 'max_depth': 46, 'min_samples_split': 12, 'min_samples_leaf': 7}. Best is trial 6 with value: -0.7568127659020003.
# [I 2024-02-05 16:45:27,045] Trial 8 finished with value: -2.8126214321817455 and parameters: {'n_estimators': 368, 'max_depth': 27, 'min_samples_split': 30, 'min_samples_leaf': 27}. Best is trial 6 with value: -0.7568127659020003.
# [I 2024-02-05 16:45:38,591] Trial 9 finished with value: -1.1961494064150444 and parameters: {'n_estimators': 740, 'max_depth': 43, 'min_samples_split': 3, 'min_samples_leaf': 8}. Best is trial 6 with value: -0.7568127659020003.
# [I 2024-02-05 16:45:40,527] Trial 10 finished with value: -0.31724842155535943 and parameters: {'n_estimators': 113, 'max_depth': 10, 'min_samples_split': 8, 'min_samples_leaf': 1}. Best is trial 10 with value: -0.31724842155535943.
# [I 2024-02-05 16:45:42,451] Trial 11 finished with value: -0.34331233101063974 and parameters: {'n_estimators': 112, 'max_depth': 10, 'min_samples_split': 7, 'min_samples_leaf': 2}. Best is trial 10 with value: -0.31724842155535943.
# [I 2024-02-05 16:45:44,585] Trial 12 finished with value: -0.2183981336110632 and parameters: {'n_estimators': 124, 'max_depth': 10, 'min_samples_split': 4, 'min_samples_leaf': 1}. Best is trial 12 with value: -0.2183981336110632.
# [I 2024-02-05 16:45:46,526] Trial 13 finished with value: -0.2833252360845373 and parameters: {'n_estimators': 108, 'max_depth': 17, 'min_samples_split': 2, 'min_samples_leaf': 2}. Best is trial 12 with value: -0.2183981336110632.
# [I 2024-02-05 16:46:01,257] Trial 14 finished with value: -1.8698415597090385 and parameters: {'n_estimators': 955, 'max_depth': 17, 'min_samples_split': 2, 'min_samples_leaf': 13}. Best is trial 12 with value: -0.2183981336110632.
# [I 2024-02-05 16:46:04,751] Trial 15 finished with value: -2.4836340321248267 and parameters: {'n_estimators': 219, 'max_depth': 31, 'min_samples_split': 6, 'min_samples_leaf': 22}. Best is trial 12 with value: -0.2183981336110632.
# [I 2024-02-05 16:46:11,735] Trial 16 finished with value: -1.5774842655161554 and parameters: {'n_estimators': 441, 'max_depth': 17, 'min_samples_split': 2, 'min_samples_leaf': 11}. Best is trial 12 with value: -0.2183981336110632.
# [I 2024-02-05 16:46:15,644] Trial 17 finished with value: -0.5097177246313855 and parameters: {'n_estimators': 238, 'max_depth': 33, 'min_samples_split': 11, 'min_samples_leaf': 3}. Best is trial 12 with value: -0.2183981336110632.
# [I 2024-02-05 16:46:18,423] Trial 18 finished with value: -1.5890797761848139 and parameters: {'n_estimators': 164, 'max_depth': 15, 'min_samples_split': 6, 'min_samples_leaf': 11}. Best is trial 12 with value: -0.2183981336110632.
# [I 2024-02-05 16:46:25,456] Trial 19 finished with value: -1.0147362916675635 and parameters: {'n_estimators': 452, 'max_depth': 21, 'min_samples_split': 25, 'min_samples_leaf': 5}. Best is trial 12 with value: -0.2183981336110632.
# Best parameters found:  {'n_estimators': 124, 'max_depth': 10, 'min_samples_split': 4, 'min_samples_leaf': 1}
