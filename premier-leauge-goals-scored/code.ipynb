# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r'D:\NEU\Năm 3\DATA PREP\Data\premier-leauage-goal-scores.csv')
data
# Out:
#               Club  Goals
# 0          Arsenal     13
# 1         Man City     14
# 2      Aston Villa      8
# 3      Bournemouth      7
# 4        Brentford     10
# 5         Brighton     16
# 6          Burnley      6
# 7         Chealsea     10
# 8        C. Palace      5
# 9          Everton      3
# 10         Fullham      4
# 11       Liverpool     19
# 12      Luton Town      5
# 13      Man United      1
# 14      Newcatstle     20
# 15  Nottin' Forest      8
# 16       Sheff Utd      2
# 17       Tottenham     11
# 18        West Ham      9
# 19          Wolves      4

# %%
data = data.sort_values(by='Goals', ascending=True)
data['total'] = data['Goals'].max()
data = data.reset_index()
data['index'] = list(range(20))
data
# Out:
#     index            Club  Goals  total
# 0       0      Man United      1     20
# 1       1       Sheff Utd      2     20
# 2       2         Everton      3     20
# 3       3         Fullham      4     20
# 4       4          Wolves      4     20
# 5       5       C. Palace      5     20
# 6       6      Luton Town      5     20
# 7       7         Burnley      6     20
# 8       8     Bournemouth      7     20
# 9       9     Aston Villa      8     20
# 10     10  Nottin' Forest      8     20
# 11     11        West Ham      9     20
# 12     12        Chealsea     10     20
# 13     13       Brentford     10     20
# 14     14       Tottenham     11     20
# 15     15         Arsenal     13     20
# 16     16        Man City     14     20
# 17     17        Brighton     16     20
# 18     18       Liverpool     19     20
# 19     19      Newcatstle     20     20

# %%
fig, ax = plt.subplots(figsize=(9, 10))
ax.barh(data['index'], data['total'], height=0.8, color='#F5F5F5', alpha=0.7)
ax.barh(data['index'], data['Goals'], height=0.8, color='#151D6F')
ax.spines[['left', 'right', 'top', 'bottom']].set_visible(False)
ax.set_yticks(list(range(20)))

# annotate the number of goals of each club
for i in range(len(data)):
    ax.annotate(xy=(0.2, data['index'][i]-0.15),
                text='{}'.format(data['Goals'][i]), color='#F5F5F5', size=11.5)


# add title and subtitle
ax.text(x=5, y=21.1, s='Goals scored by forwards',
        weight='bold', color='black', size=17.0, alpha=0.7)
ax.text(x=6, y=20.3, s='Premier Leauge 2023 - 2024', color='#B2B2B2', size=13)

# modify ticks
ax.set_yticklabels(list(data['Club']))
ax.set_xticks([])
ax.tick_params(left=False, bottom=False)
ax.set_ylim(ymin=-0.5)

# highlight MU position
ax.get_yticklabels()[0].set_color('maroon')
